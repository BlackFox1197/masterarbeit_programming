# %%
import json

import matplotlib.pyplot as plt

with open("/home/ckwdani/Programming/Projects/masterarbeit/Jupyter/mainProject/notebooks_clip/content/models/clip_based_classifiers/0_2_seconds/_statistics.json", encoding='utf-8') as f:
    dict = json.load(f)

# %%
plt.plot(dict["train_losses"])

# %%
plt.plot(dict["eval_losses"])

# %%
# Out:
# ['mesd', 'mesd', 'mesd', 'mesd', 'mesd']

# %%
plt.plot(dict["eval_accs"])
