# %%
import json

import matplotlib.pyplot as plt

with open("/home/ckwdani/Programming/Projects/masterarbeit/Jupyter/mainProject/notebooks_clip/content/models/clip_models/clip_full_dataset_0_2_sec__loss.json", encoding='utf-8') as f:
    dict = json.load(f)

with open("/home/ckwdani/Programming/Projects/masterarbeit/Jupyter/mainProject/notebooks_clip/content/models/clip_models/clip_full_dataset_0_2_sec__loss.json", encoding='utf-8') as f:
    arr_0_2 = json.load(f)

with open("/home/ckwdani/Programming/Projects/masterarbeit/Jupyter/mainProject/notebooks_clip/content/models/clip_models/clip_full_dataset_1_sec__loss.json", encoding='utf-8') as f:
    arr_1 = json.load(f)

# with open("/home/ckwdani/Programming/Projects/masterarbeit/Jupyter/mainProject/notebooks_clip/content/models/clip_models/clip_full_dataset_3_5_sec__loss.json", encoding='utf-8') as f:
#     arr_3_5 = json.load(f)

with open("/home/ckwdani/Programming/Projects/masterarbeit/Jupyter/mainProject/notebooks_clip/content/models/clip_models/clip_full_dataset_5_sec__loss.json", encoding='utf-8') as f:
    arr_5 = json.load(f)

# %%
plt.plot(arr_5)

# %%
plt.plot(dict["train_losses"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.plot(dict["train_losses"])
#
# TypeError: list indices must be integers or slices, not str

# %%
plt.plot(dict["eval_losses"])

# %%
plt.plot(dict["eval_accs"])
